# %%
import os
import shutil
import json
import torch
import time
import nltk
import numpy as np
from google.colab import drive

# 1. CÀI ĐẶT THƯ VIỆN & CẤP QUYỀN NUMPY
os.system("pip install -q peft")
from peft import PeftModel
from transformers import T5Tokenizer, T5ForConditionalGeneration
from datasets import Dataset

try:
    reconstruct_func = np._core.multiarray._reconstruct if hasattr(np, '_core') else np.core.multiarray._reconstruct
    torch.serialization.add_safe_globals([
        reconstruct_func,
        np.ndarray,
        np.dtype,
    ])
    print("✅ Đã whitelist Numpy cho PyTorch.")
except AttributeError:
    pass

if not hasattr(torch, 'original_load_func'):
    torch.original_load_func = torch.load

def safe_load_override(*args, **kwargs):
    if 'weights_only' in kwargs:
        del kwargs['weights_only']
    return torch.original_load_func(*args, weights_only=False, **kwargs)

torch.load = safe_load_override
print(f"✅ Đã ép buộc torch.load(weights_only=False) thành công.")

# 2. KẾT NỐI DRIVE & TẢI DỮ LIỆU
os.environ['KAGGLE_USERNAME'] = "phankhaclap"
os.environ['KAGGLE_KEY'] = "0ba946628cb1f5acb76ecd357f590e95"

drive.mount('/content/drive')
FINAL_SAVE_PATH = "/content/drive/My Drive/T5_Small_Spider_CRP_LoRA"

print(">>> [1/4] Kiểm tra và tải dữ liệu...")
if not os.path.exists('spider_data'):
    os.system("pip install -q kaggle")
    os.system("kaggle datasets download -d jeromeblanchet/yale-universitys-spider-10-nlp-dataset")
    os.system("unzip -q yale-universitys-spider-10-nlp-dataset.zip -d temp_spider")

    if os.path.exists("temp_spider/spider"):
        shutil.move("temp_spider/spider", "spider_data")
        shutil.rmtree('temp_spider')
        os.system("wget -q https://raw.githubusercontent.com/taoyds/spider/master/evaluation.py")
        os.system("wget -q https://raw.githubusercontent.com/taoyds/spider/master/process_sql.py")
        nltk.download('punkt', quiet=True)
        nltk.download('punkt_tab', quiet=True)

# Tải thêm tập Spider-Realistic
if not os.path.exists('spider_data/spider-realistic.json'):
    os.system("wget -q -O spider_data/spider-realistic.json \"https://zenodo.org/records/5205322/files/spider-realistic.json?download=1\"")

# 3. TIỀN XỬ LÝ SCHEMA
with open('spider_data/tables.json', 'r') as f:
    table_data = json.load(f)
schema_map = {db['db_id']: db for db in table_data}

def get_crp_schema(db_id):
    if db_id not in schema_map: return ""
    db = schema_map[db_id]
    ddl_statements = []
    for i, table_name in enumerate(db['table_names_original']):
        col_defs = [f"{c[1]} {db['column_types'][j]}" for j, c in enumerate(db['column_names_original']) if c[0] == i]
        pk_idx = db['primary_keys']
        pks = [db['column_names_original'][j][1] for j in pk_idx if db['column_names_original'][j][0] == i]
        if pks: col_defs.append(f"primary key ({', '.join(pks)})")
        for fk in db['foreign_keys']:
            if db['column_names_original'][fk[0]][0] == i:
                from_col = db['column_names_original'][fk[1]][1]
                to_table = db['table_names_original'][db['column_names_original'][fk[1]][0]]
                to_col = db['column_names_original'][fk[1]][1]
                col_defs.append(f"foreign key ({from_col}) references {to_table}({to_col})")
        ddl_statements.append(f"CREATE TABLE {table_name} ({', '.join(col_defs)});")
    return " ".join(ddl_statements)

def load_spider_unified(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    return Dataset.from_dict({
        "question": [item["question"] for item in data],
        "query": [item["query"] for item in data],
        "db_id": [item["db_id"] for item in data]
    })

print(">>> [2/4] Đang load tập Spider-Realistic...")
val_ds = load_spider_unified("spider_data/spider-realistic.json")

# 4. LOAD MÔ HÌNH LORA (T5-SMALL)
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"\n>>> [3/4] Đang tải mô hình LoRA lên {device}...")

MODEL_NAME = "t5-small"
tokenizer = T5Tokenizer.from_pretrained(FINAL_SAVE_PATH)

# Load model T5 gốc trước
base_model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME)
# Ghép trọng số LoRA vào model gốc
model = PeftModel.from_pretrained(base_model, FINAL_SAVE_PATH)
model = model.to(device)
model.eval()

# 5. CHẠY INFERENCE (BATCH) & ĐÁNH GIÁ
print("\n>>> [4/4] Bắt đầu Inference (Batch Processing)...")
predictions, gold_lines = [], []
input_texts = []

for item in val_ds:
    input_texts.append(f"translate to SQL: {item['question']} | Schema: {get_crp_schema(item['db_id'])}")
    gold_lines.append(f"{item['query']}\t{item['db_id']}\n")

batch_size = 16
total_batches = len(input_texts)
print(f"Bắt đầu dịch {total_batches} câu hỏi sang SQL...")
start_time = time.time()

for i in range(0, total_batches, batch_size):
    batch_texts = input_texts[i : i + batch_size]

    # max_length=1024 theo đúng config cũ của bạn
    inputs = tokenizer(batch_texts, return_tensors="pt", padding=True, truncation=True, max_length=1024)

    input_ids = inputs.input_ids.to(model.device)
    attention_mask = inputs.attention_mask.to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            input_ids=input_ids,
            attention_mask=attention_mask,
            max_length=128,
            num_beams=8, # Sử dụng beam=8 như trong file cũ
            early_stopping=True
        )

    batch_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    predictions.extend([pred + "\n" for pred in batch_preds])

    print(f"\rĐã xử lý: {min(i + batch_size, total_batches)}/{total_batches}", end="")

print(f"\n✅ Xong Inference trong {time.time() - start_time:.2f} giây!")

with open('pred.txt', 'w') as f: f.writelines(predictions)
with open('gold.txt', 'w') as f: f.writelines(gold_lines)

print("\n>>> KẾT QUẢ ĐÁNH GIÁ TRÊN SPIDER-REALISTIC:")
os.system('sed -i \'s/conn = sqlite3.connect(db)/conn = sqlite3.connect(db)\\n    conn.text_factory = lambda b: b.decode(errors="ignore")/\' evaluation.py')
os.system('python evaluation.py --gold gold.txt --pred pred.txt --db spider_data/database --table spider_data/tables.json --etype all')
# Out:
# ✅ Đã whitelist Numpy cho PyTorch.
# ✅ Đã ép buộc torch.load(weights_only=False) thành công.
# Mounted at /content/drive
# >>> [1/4] Kiểm tra và tải dữ liệu...
# >>> [2/4] Đang load tập Spider-Realistic...
#
# >>> [3/4] Đang tải mô hình LoRA lên cuda...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/131 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# >>> [4/4] Bắt đầu Inference (Batch Processing)...
# Bắt đầu dịch 508 câu hỏi sang SQL...
# Đã xử lý: 508/508
# ✅ Xong Inference trong 102.03 giây!
#
# >>> KẾT QUẢ ĐÁNH GIÁ TRÊN SPIDER-REALISTIC:
# 0

# %%
print("\n>>> [5/5] Kết quả đánh giá:")
# !sed -i 's/conn = sqlite3.connect(db)/conn = sqlite3.connect(db)\n    conn.text_factory = lambda b: b.decode(errors="ignore")/' evaluation.py
# !python evaluation.py --gold gold.txt --pred pred.txt --db spider_data/database --table spider_data/tables.json --etype all
# Out:
# >>> [5/5] Kết quả đánh giá:
# medium pred: SELECT name, country, age FROM singer ORDER BY age DESC LIMIT 1
# medium gold: SELECT name ,  country ,  age FROM singer ORDER BY age DESC
#
# eval_err_num:1
# medium pred: SELECT T1.name, T1.year FROM singer AS T1 JOIN singer_in_concert AS T2 ON T1.singer_id = T2.singer_id ORDER BY T2.age DESC LIMIT 1
# medium gold: SELECT song_name ,  song_release_year FROM singer ORDER BY age LIMIT 1
#
# medium pred: SELECT Song_release_year, Song_release_year FROM singer ORDER BY Age DESC LIMIT 1
# medium gold: SELECT song_name ,  song_release_year FROM singer ORDER BY age LIMIT 1
#
# eval_err_num:2
# hard pred: SELECT T1.name FROM singer AS T1 JOIN singer_in_concert AS T2 ON T1.singer_id = T2.singer_id WHERE T2.age > (SELECT avg(age) FROM singer)
# hard gold: SELECT song_name FROM singer WHERE age  >  (SELECT avg(age) FROM singer)
#
# eval_err_num:3
# hard pred: SELECT T1.name FROM singer AS T1 JOIN singer_in_concert AS T2 ON T1.singer_id = T2.singer_id WHERE T2.age > (SELECT avg(age) FROM singer)
# hard gold: SELECT song_name FROM singer WHERE age  >  (SELECT avg(age) FROM singer)
#
# eval_err_num:4
# medium pred: SELECT LOCATION, T1.Name FROM stadium AS T1 JOIN concert AS T2 ON T1.Stadium_ID = T2.Stadium_ID WHERE T2.Capacity BETWEEN 5000 AND 10000
# medium gold: SELECT LOCATION ,  name FROM stadium WHERE capacity BETWEEN 5000 AND 10000
#
# eval_err_num:5
# medium pred: SELECT LOCATION, T1.Name FROM stadium AS T1 JOIN concert AS T2 ON T1.Stadium_ID = T2.Stadium_ID WHERE T2.Capacity BETWEEN 5000 AND 10000
# medium gold: SELECT LOCATION ,  name FROM stadium WHERE capacity BETWEEN 5000 AND 10000
#
# eval_err_num:6
# extra pred: SELECT name, capacity FROM stadium WHERE YEAR > 2014 OR YEAR >= 2014 GROUP BY name ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT T2.name ,  T2.capacity FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.year  >=  2014 GROUP BY T2.stadium_id ORDER BY count(*) DESC LIMIT 1
#
# eval_err_num:7
# extra pred: SELECT name, capacity FROM stadium WHERE YEAR > 2013 GROUP BY name ORDER BY count(*) DESC LIMIT 1
# extra gold: select t2.name ,  t2.capacity from concert as t1 join stadium as t2 on t1.stadium_id  =  t2.stadium_id where t1.year  >  2013 group by t2.stadium_id order by count(*) desc limit 1
#
# eval_err_num:8
# hard pred: SELECT Country FROM singer WHERE age  40 INTERSECT SELECT Country FROM singer WHERE age  30
# hard gold: SELECT country FROM singer WHERE age  >  40 INTERSECT SELECT country FROM singer WHERE age  <  30
#
# hard pred: SELECT T1.name FROM stadium AS T1 JOIN concert AS T2 ON T1.stadium_id = T2.stadium_id WHERE T2.year = 2014 GROUP BY T1.name ORDER BY count(*) DESC LIMIT 1
# hard gold: SELECT name FROM stadium EXCEPT SELECT T2.name FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.year  =  2014
#
# eval_err_num:9
# hard pred: SELECT name FROM stadium WHERE YEAR!= 2014
# hard gold: SELECT name FROM stadium EXCEPT SELECT T2.name FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.year  =  2014
#
# eval_err_num:10
# medium pred: SELECT T1.name, T1.theme, count(*) FROM concert AS T1 JOIN singer_in_concert AS T2 ON T1.concert_id = T2.concert_id GROUP BY T1.concert_id
# medium gold: SELECT T2.concert_name ,  T2.theme ,  count(*) FROM singer_in_concert AS T1 JOIN concert AS T2 ON T1.concert_id  =  T2.concert_id GROUP BY T2.concert_id
#
# eval_err_num:11
# medium pred: SELECT T1.name, count(*) FROM concert AS T1 JOIN singer_in_concert AS T2 ON T1.concert_id = T2.concert_id GROUP BY T1.name
# medium gold: SELECT T2.name ,  count(*) FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id GROUP BY T2.singer_id
#
# eval_err_num:12
# medium pred: SELECT T1.name, count(*) FROM concert AS T1 JOIN concert AS T2 ON T1.concert_id = T2.concert_id GROUP BY T1.concert_id
# medium gold: SELECT T2.name ,  count(*) FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id GROUP BY T2.singer_id
#
# eval_err_num:13
# hard pred: SELECT T1.name FROM singer_in_concert AS T1 JOIN concert AS T2 ON T1.concert_id = T2.concert_id WHERE YEAR = 2014
# hard gold: SELECT T2.name FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id JOIN concert AS T3 ON T1.concert_id  =  T3.concert_id WHERE T3.year  =  2014
#
# eval_err_num:14
# hard pred: SELECT T1.name FROM singer_in_concert AS T1 JOIN concert AS T2 ON T1.concert_id = T2.concert_id WHERE YEAR = 2014
# hard gold: SELECT T2.name FROM singer_in_concert AS T1 JOIN singer AS T2 ON T1.singer_id  =  T2.singer_id JOIN concert AS T3 ON T1.concert_id  =  T3.concert_id WHERE T3.year  =  2014
#
# medium pred: SELECT T1.name, T1.country FROM singer AS T1 JOIN singer_in_concert AS T2 ON T1.singer_id = T2.singer_id WHERE T1.name LIKE '%Hey%'
# medium gold: SELECT name ,  country FROM singer WHERE song_name LIKE '%Hey%'
#
# eval_err_num:15
# medium pred: SELECT T1.name, T1.country FROM singer AS T1 JOIN singer_in_concert AS T2 ON T1.singer_id = T2.singer_id WHERE T2.name LIKE '%Hey%'
# medium gold: SELECT name ,  country FROM singer WHERE song_name LIKE '%Hey%'
#
# extra pred: SELECT T1.name, T1.location FROM stadium AS T1 JOIN concert AS T2 ON T1.stadium_id = T2.stadium_id WHERE YEAR = 2014 INTERSECT SELECT T1.location, T1.location FROM stadium AS T1 JOIN concert AS T2 ON T1.stadium_id = T2.stadium_id WHERE T2.year = 2015
# extra gold: SELECT T2.name ,  T2.location FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.Year  =  2014 INTERSECT SELECT T2.name ,  T2.location FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.Year  =  2015
#
# eval_err_num:16
# extra pred: SELECT name, LOCATION FROM stadium WHERE YEAR = 2014 INTERSECT SELECT name, LOCATION FROM concert WHERE YEAR = 2015
# extra gold: SELECT T2.name ,  T2.location FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.Year  =  2014 INTERSECT SELECT T2.name ,  T2.location FROM concert AS T1 JOIN stadium AS T2 ON T1.stadium_id  =  T2.stadium_id WHERE T1.Year  =  2015
#
# hard pred: SELECT count(*) FROM stadium GROUP BY stadium_id ORDER BY count(*) DESC LIMIT 1
# hard gold: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
#
# hard pred: SELECT count(*) FROM stadium GROUP BY stadium_id ORDER BY count(*) DESC LIMIT 1
# hard gold: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
#
# eval_err_num:17
# medium pred: SELECT weight FROM Pets ORDER BY age DESC LIMIT 1
# medium gold: SELECT weight FROM pets ORDER BY pet_age LIMIT 1
#
# medium pred: SELECT count(*) FROM Has_Pet AS T1 JOIN Pets AS T2 ON T1.PetID = T2.PetID GROUP BY T1.PetID ORDER BY count(*) DESC LIMIT 1
# medium gold: SELECT weight FROM pets ORDER BY pet_age LIMIT 1
#
# medium pred: SELECT count(*) FROM Student WHERE age > 20
# medium gold: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.age  >  20
#
# medium pred: SELECT count(*) FROM Student WHERE age > 20
# medium gold: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.age  >  20
#
# hard pred: SELECT count(*) FROM Student WHERE Sex = "F"
# hard gold: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T2.petid  =  T3.petid WHERE T1.sex  =  'F' AND T3.pettype  =  'dog'
#
# hard pred: SELECT count(*) FROM Student WHERE Sex = "F"
# hard gold: SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T2.petid  =  T3.petid WHERE T1.sex  =  'F' AND T3.pettype  =  'dog'
#
# eval_err_num:18
# extra pred: SELECT fname FROM Student WHERE StuID IN (SELECT StuID FROM Has_Pet WHERE StuID IN (SELECT StuID FROM Has_Pet WHERE StuID IN (SELECT StuID FROM Has_Pet)
# extra gold: SELECT DISTINCT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat' OR T3.pettype  =  'dog'
#
# eval_err_num:19
# extra pred: SELECT fname FROM Student WHERE StuID IN (SELECT StuID FROM Has_Pet WHERE StuID IN (SELECT StuID FROM Has_Pet WHERE StuID IN (SELECT StuID FROM Has_Pet)
# extra gold: SELECT DISTINCT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat' OR T3.pettype  =  'dog'
#
# eval_err_num:20
# extra pred: SELECT fname FROM Student WHERE StuID IN (SELECT StuID FROM Has_Pet WHERE StuID IN (SELECT StuID FROM Has_Pet WHERE StuID IN (SELECT StuID FROM Has_Pet WHERE StuID IN (SELECT StuID FROM Has_Pet WHERE StuID IN (SELECT StuID FROM Has_Pet)
# extra gold: select t1.fname from student as t1 join has_pet as t2 on t1.stuid  =  t2.stuid join pets as t3 on t3.petid  =  t2.petid where t3.pettype  =  'cat' intersect select t1.fname from student as t1 join has_pet as t2 on t1.stuid  =  t2.stuid join pets as t3 on t3.petid  =  t2.petid where t3.pettype  =  'dog'
#
# eval_err_num:21
# extra pred: SELECT fname FROM Student WHERE StuID IN (SELECT StuID FROM Has_Pet WHERE StuID IN (SELECT StuID FROM Has_Pet WHERE StuID IN (SELECT StuID FROM Has_Pet)
# extra gold: SELECT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat' INTERSECT SELECT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'dog'
#
# eval_err_num:22
# extra pred: SELECT major, age FROM Student WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE )
# extra gold: SELECT major ,  age FROM student WHERE stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat')
#
# eval_err_num:23
# extra pred: SELECT major FROM Student WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE StuID IN (SELECT StuID FROM Has_Pet WHERE StuID IN (SELECT StuID FROM Has_Pet WHERE StuID IN (SELECT DISTINCT SELECT Major FROM Student WHERE
# extra gold: SELECT major ,  age FROM student WHERE stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat')
#
# eval_err_num:24
# hard pred: SELECT StuID FROM Student WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE StuID NOT IN (SELECT StuID FROM Has_Pet)
# hard gold: SELECT stuid FROM student EXCEPT SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat'
#
# eval_err_num:25
# hard pred: SELECT StuID FROM Student WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE StuID NOT IN (SELECT StuID FROM Has_Pet)
# hard gold: SELECT stuid FROM student EXCEPT SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat'
#
# eval_err_num:26
# extra pred: SELECT fname, age FROM Student WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE pet_age = "cat")
# extra gold: SELECT T1.fname ,  T1.age FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'dog' AND T1.stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat')
#
# eval_err_num:27
# extra pred: SELECT fname FROM Student WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE StuID NOT IN (SELECT StuID FROM Has_Pet WHERE StuID NOT IN (SELECT SELECT DISTINCT
# extra gold: SELECT T1.fname ,  T1.age FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'dog' AND T1.stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat')
#
# medium pred: SELECT T2.PetType, T2.weight FROM Has_Pet AS T1 JOIN Pets AS T2 ON T1.PetID = T2.PetID ORDER BY T2.weight DESC LIMIT 1
# medium gold: SELECT pettype ,  weight FROM pets ORDER BY pet_age LIMIT 1
#
# medium pred: SELECT T2.PetType, COUNT(*) FROM Has_Pet AS T1 JOIN Pets AS T2 ON T1.PetID = T2.PetID GROUP BY T1.PetID ORDER BY count(*) DESC LIMIT 1
# medium gold: SELECT pettype ,  weight FROM pets ORDER BY pet_age LIMIT 1
#
# eval_err_num:28
# medium pred: SELECT T2.PetID, T2.weight FROM Has_Pet AS T1 JOIN Pets AS T2 ON T1.PetID = T2.PetID WHERE T2.age > 1
# medium gold: SELECT petid ,  weight FROM pets WHERE pet_age  >  1
#
# hard pred: SELECT fname FROM Student WHERE age = 3
# hard gold: SELECT T1.lname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pet_age  =  3 AND T3.pettype  =  'cat'
#
# hard pred: SELECT fname FROM Student WHERE age = 3
# hard gold: SELECT T1.lname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pet_age  =  3 AND T3.pettype  =  'cat'
#
# medium pred: SELECT maker, id, count(*) FROM car_makers GROUP BY maker
# medium gold: SELECT T1.FullName ,  T1.Id ,  count(*) FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id;
#
# medium pred: SELECT fullname, id, count(*) FROM car_makers GROUP BY id
# medium gold: SELECT T1.FullName ,  T1.Id ,  count(*) FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id;
#
# eval_err_num:29
# extra pred: SELECT DISTINCT t1.model FROM models AS t1 JOIN cars_data AS t2 ON t1.model = t2.model WHERE weight  (SELECT avg(weight) FROM cars_data)
# extra gold: SELECT T1.model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.Weight  <  (SELECT avg(Weight) FROM CARS_DATA)
#
# eval_err_num:30
# extra pred: SELECT model FROM cars_data WHERE weight  (SELECT avg(weight) FROM cars_data)
# extra gold: SELECT T1.model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.Weight  <  (SELECT avg(Weight) FROM CARS_DATA)
#
# eval_err_num:31
# extra pred: SELECT T2.Make FROM models AS T1 JOIN car_makers AS T2 ON T1.MakeId = T2.MakeId WHERE T2.Year = 1970
# extra gold: SELECT DISTINCT T1.Maker FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker JOIN CAR_NAMES AS T3 ON T2.model  =  T3.model JOIN CARS_DATA AS T4 ON T3.MakeId  =  T4.id WHERE T4.year  =  '1970';
#
# eval_err_num:32
# extra pred: SELECT DISTINCT Maker FROM car_makers WHERE YEAR = 1970
# extra gold: SELECT DISTINCT T1.Maker FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker JOIN CAR_NAMES AS T3 ON T2.model  =  T3.model JOIN CARS_DATA AS T4 ON T3.MakeId  =  T4.id WHERE T4.year  =  '1970';
#
# eval_err_num:33
# extra pred: SELECT T2.make, T2.year FROM cars_data AS T1 JOIN countries AS T2 ON T1.CountryId = T2.CountryId GROUP BY T1.MakeId ORDER BY T2.Year DESC LIMIT 1
# extra gold: SELECT T2.Make ,  T1.Year FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T1.Year  =  (SELECT min(YEAR) FROM CARS_DATA);
#
# eval_err_num:34
# extra pred: SELECT Maker FROM car_makers ORDER BY YEAR DESC LIMIT 1
# extra gold: SELECT T2.Make ,  T1.Year FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T1.Year  =  (SELECT min(YEAR) FROM CARS_DATA);
#
# eval_err_num:35
# hard pred: SELECT DISTINCT Model FROM car_names WHERE YEAR > 1980
# hard gold: SELECT DISTINCT T1.model FROM MODEL_LIST AS T1 JOIN CAR_NAMES AS T2 ON T1.model  =  T2.model JOIN CARS_DATA AS T3 ON T2.MakeId  =  T3.id WHERE T3.year  >  1980;
#
# eval_err_num:36
# hard pred: SELECT DISTINCT Model FROM car_names WHERE YEAR > 1980
# hard gold: SELECT DISTINCT T1.model FROM MODEL_LIST AS T1 JOIN CAR_NAMES AS T2 ON T1.model  =  T2.model JOIN CARS_DATA AS T3 ON T2.MakeId  =  T3.id WHERE T3.year  >  1980;
#
# eval_err_num:37
# extra pred: SELECT CountryName FROM car_makers GROUP BY Country ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT T2.CountryName FROM CAR_MAKERS AS T1 JOIN COUNTRIES AS T2 ON T1.Country  =  T2.CountryId GROUP BY T1.Country ORDER BY Count(*) DESC LIMIT 1;
#
# eval_err_num:38
# extra pred: SELECT T1.CountryName FROM countries AS T1 JOIN car_makers AS T2 ON T1.CountryId = T2.CountryId GROUP BY T1.CountryId ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT T2.CountryName FROM CAR_MAKERS AS T1 JOIN COUNTRIES AS T2 ON T1.Country  =  T2.CountryId GROUP BY T1.Country ORDER BY Count(*) DESC LIMIT 1;
#
# medium pred: SELECT count(*), maker FROM car_makers GROUP BY maker
# medium gold: select count(*) ,  t2.fullname from model_list as t1 join car_makers as t2 on t1.maker  =  t2.id group by t2.id;
#
# medium pred: SELECT count(*), id, fullname FROM car_makers GROUP BY maker
# medium gold: SELECT Count(*) ,  T2.FullName ,  T2.id FROM MODEL_LIST AS T1 JOIN CAR_MAKERS AS T2 ON T1.Maker  =  T2.Id GROUP BY T2.id;
#
# medium pred: SELECT Accelerate FROM cars_data ORDER BY Accelerate DESC LIMIT 1
# medium gold: SELECT T1.Accelerate FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T2.Make  =  'amc hornet sportabout (sw)';
#
# eval_err_num:39
# medium pred: SELECT count(*) FROM car_makers AS T1 JOIN countries AS T2 ON T1.CountryId = T2.CountryId WHERE T1.Country = "France"
# medium gold: SELECT count(*) FROM CAR_MAKERS AS T1 JOIN COUNTRIES AS T2 ON T1.Country  =  T2.CountryId WHERE T2.CountryName  =  'france';
#
# eval_err_num:40
# medium pred: SELECT count(*) FROM car_makers AS T1 JOIN countries AS T2 ON T1.CountryId = T2.CountryId WHERE T1.Country = "France"
# medium gold: SELECT count(*) FROM CAR_MAKERS AS T1 JOIN COUNTRIES AS T2 ON T1.Country  =  T2.CountryId WHERE T2.CountryName  =  'france';
#
# eval_err_num:41
# hard pred: SELECT count(*) FROM car_names AS T1 JOIN countries AS T2 ON T1.CountryId = T2.CountryId WHERE T1.Country = "United States"
# hard gold: SELECT count(*) FROM MODEL_LIST AS T1 JOIN CAR_MAKERS AS T2 ON T1.Maker  =  T2.Id JOIN COUNTRIES AS T3 ON T2.Country  =  T3.CountryId WHERE T3.CountryName  =  'usa';
#
# eval_err_num:42
# hard pred: SELECT count(*) FROM car_names AS T1 JOIN countries AS T2 ON T1.CountryId = T2.CountryId WHERE T2.Country = "United States"
# hard gold: SELECT count(*) FROM MODEL_LIST AS T1 JOIN CAR_MAKERS AS T2 ON T1.Maker  =  T2.Id JOIN COUNTRIES AS T3 ON T2.Country  =  T3.CountryId WHERE T3.CountryName  =  'usa';
#
# eval_err_num:43
# easy pred: SELECT avg(MPG), avg(MPG), COUNT(*) FROM cars_data AS T1 JOIN countries AS T2 ON T1.CountryId = T2.CountryId WHERE T1.Country = 4
# easy gold: SELECT avg(mpg) FROM CARS_DATA WHERE Cylinders  =  4;
#
# medium pred: SELECT weight FROM cars_data WHERE YEAR = 1974 GROUP BY weight ORDER BY count(*) DESC LIMIT 8
# medium gold: select min(weight) from cars_data where cylinders  =  8 and year  =  1974
#
# eval_err_num:44
# medium pred: SELECT T1.Country, T1.Country FROM countries AS T1 JOIN car_makers AS T2 ON T1.CountryId = T2.CountryId GROUP BY T1.CountryId HAVING count(*) >= 1
# medium gold: SELECT T1.CountryName ,  T1.CountryId FROM COUNTRIES AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country GROUP BY T1.CountryId HAVING count(*)  >=  1;
#
# eval_err_num:45
# medium pred: SELECT T1.CountryName, T1.Country FROM countries AS T1 JOIN car_makers AS T2 ON T1.CountryId = T2.CountryId GROUP BY T1.CountryId HAVING count(*) >= 1
# medium gold: SELECT T1.CountryName ,  T1.CountryId FROM COUNTRIES AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country GROUP BY T1.CountryId HAVING count(*)  >=  1;
#
# easy pred: SELECT count(*) FROM cars_data WHERE weight > 150 INTERSECT SELECT count(*) FROM cars_data WHERE weight > 150
# easy gold: SELECT count(*) FROM CARS_DATA WHERE horsepower  >  150;
#
# easy pred: SELECT count(*) FROM cars_data WHERE weight > 150 INTERSECT SELECT count(*) FROM cars_data WHERE weight > 150
# easy gold: SELECT count(*) FROM CARS_DATA WHERE horsepower  >  150;
#
# eval_err_num:46
# extra pred: SELECT Country FROM countries WHERE Country = 'Europa' GROUP BY Country HAVING count(*) >= 3
# extra gold: SELECT T1.CountryName FROM COUNTRIES AS T1 JOIN CONTINENTS AS T2 ON T1.Continent  =  T2.ContId JOIN CAR_MAKERS AS T3 ON T1.CountryId  =  T3.Country WHERE T2.Continent  =  'europe' GROUP BY T1.CountryName HAVING count(*)  >=  3;
#
# eval_err_num:47
# extra pred: SELECT CountryName FROM countries WHERE Country = "European" GROUP BY Country HAVING COUNT(*) >= 3
# extra gold: SELECT T1.CountryName FROM COUNTRIES AS T1 JOIN CONTINENTS AS T2 ON T1.Continent  =  T2.ContId JOIN CAR_MAKERS AS T3 ON T1.CountryId  =  T3.Country WHERE T2.Continent  =  'europe' GROUP BY T1.CountryName HAVING count(*)  >=  3;
#
# eval_err_num:48
# hard pred: SELECT Model FROM cars_data ORDER BY Edispl DESC LIMIT 1
# hard gold: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id ORDER BY T2.mpg DESC LIMIT 1;
#
# eval_err_num:49
# hard pred: SELECT DISTINCT t1.model FROM models AS t1 JOIN cars_data AS t2 ON t1.model = t2.model ORDER BY t2.speederpower DESC LIMIT 1
# hard gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid  =  t2.id order by t2.mpg desc limit 1;
#
# eval_err_num:50
# easy pred: SELECT avg(Hitchpower) FROM cars_data WHERE YEAR  1980
# easy gold: SELECT avg(horsepower) FROM CARS_DATA WHERE YEAR  <  1980;
#
# eval_err_num:51
# easy pred: SELECT avg(Hitchpower) FROM cars_data WHERE YEAR  1980
# easy gold: select avg(horsepower) from cars_data where year  <  1980;
#
# medium pred: SELECT avg(Edispl) FROM cars_data WHERE MPG = "Volvo"
# medium gold: SELECT avg(T2.edispl) FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T1.Model  =  'volvo';
#
# eval_err_num:52
# medium pred: SELECT avg(edispl) FROM cars_data AS T1 JOIN countries AS T2 ON T1.CountryId = T2.CountryId WHERE T2.Country = "Volvo"
# medium gold: SELECT avg(T2.edispl) FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T1.Model  =  'volvo';
#
# hard pred: SELECT DISTINCT Make FROM car_names GROUP BY Make ORDER BY COUNT(*) DESC LIMIT 1
# hard gold: SELECT Model FROM CAR_NAMES GROUP BY Model ORDER BY count(*) DESC LIMIT 1;
#
# eval_err_num:53
# easy pred: SELECT count(*) FROM cars_data AS T1 JOIN countries AS T2 ON T1.CountryId = T2.CountryId WHERE T2.year = 1980
# easy gold: SELECT count(*) FROM CARS_DATA WHERE YEAR  =  1980;
#
# eval_err_num:54
# easy pred: SELECT count(*) FROM cars_data AS T1 JOIN countries AS T2 ON T1.CountryId = T2.CountryId WHERE T2.Make = 1980
# easy gold: SELECT count(*) FROM CARS_DATA WHERE YEAR  =  1980;
#
# eval_err_num:55
# medium pred: SELECT count(*) FROM car_data AS T1 JOIN manufacturers AS T2 ON T1.MakeId = T2.MakeId WHERE T2.Make = "American Motor Company"
# medium gold: SELECT count(*) FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker WHERE T1.FullName  =  'American Motor Company';
#
# eval_err_num:56
# medium pred: SELECT count(*) FROM car_names AS T1 JOIN manufacturers AS T2 ON T1.MakeId = T2.MakeId WHERE T2.Make = "American Motor Company"
# medium gold: SELECT count(*) FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker WHERE T1.FullName  =  'American Motor Company';
#
# eval_err_num:57
# medium pred: SELECT T1.FallName, T1.Id FROM car_makers AS T1 JOIN models AS T2 ON T1.MakeId = T2.MakeId GROUP BY T1.MakeId HAVING count(*) > 3
# medium gold: SELECT T1.FullName ,  T1.Id FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id HAVING count(*)  >  3;
#
# eval_err_num:58
# medium pred: SELECT T1.Name, T1.Id FROM car_makers AS T1 JOIN models AS T2 ON T1.Model = T2.Model GROUP BY T1.Model HAVING count(*) > 3
# medium gold: SELECT T1.FullName ,  T1.Id FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker GROUP BY T1.Id HAVING count(*)  >  3;
#
# eval_err_num:59
# extra pred: SELECT DISTINCT DISTINCT Model FROM cars_data WHERE Weight > 3500
# extra gold: SELECT DISTINCT T2.Model FROM CAR_NAMES AS T1 JOIN MODEL_LIST AS T2 ON T1.Model  =  T2.Model JOIN CAR_MAKERS AS T3 ON T2.Maker  =  T3.Id JOIN CARS_DATA AS T4 ON T1.MakeId  =  T4.Id WHERE T3.FullName  =  'General Motors' OR T4.weight  >  3500;
#
# eval_err_num:60
# extra pred: SELECT DISTINCT Model FROM car_names WHERE Make > 3500 lbs
# extra gold: SELECT DISTINCT T2.Model FROM CAR_NAMES AS T1 JOIN MODEL_LIST AS T2 ON T1.Model  =  T2.Model JOIN CAR_MAKERS AS T3 ON T2.Maker  =  T3.Id JOIN CARS_DATA AS T4 ON T1.MakeId  =  T4.Id WHERE T3.FullName  =  'General Motors' OR T4.weight  >  3500;
#
# extra pred: SELECT count(*) FROM cars_data WHERE Accelerate = 'Volvo' GROUP BY Accelerate ORDER BY count(*) LIMIT 1
# extra gold: SELECT T1.cylinders FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T2.Model  =  'volvo' ORDER BY T1.accelerate ASC LIMIT 1;
#
# eval_err_num:61
# extra pred: SELECT count(*) FROM cars_data AS T1 JOIN cars_data AS T2 ON T1.MakeId = T2.MakeId WHERE T1.Model = 'Volvo' ORDER BY Accelerate LIMIT 1
# extra gold: SELECT T1.cylinders FROM CARS_DATA AS T1 JOIN CAR_NAMES AS T2 ON T1.Id  =  T2.MakeId WHERE T2.Model  =  'volvo' ORDER BY T1.accelerate ASC LIMIT 1;
#
# eval_err_num:62
# medium pred: SELECT count(*) FROM countries GROUP BY country HAVING count(*) > 2
# medium gold: select count(*) from countries as t1 join car_makers as t2 on t1.countryid  =  t2.country group by t1.countryid having count(*)  >  2
#
# eval_err_num:63
# medium pred: SELECT count(*) FROM countries GROUP BY country HAVING count(*) > 2
# medium gold: select count(*) from countries as t1 join car_makers as t2 on t1.countryid  =  t2.country group by t1.countryid having count(*)  >  2
#
# eval_err_num:64
# extra pred: SELECT Model FROM cars_data ORDER BY Horsepower DESC LIMIT 4
# extra gold: SELECT T1.Model FROM CAR_NAMES AS T1 JOIN CARS_DATA AS T2 ON T1.MakeId  =  T2.Id WHERE T2.Cylinders  =  4 ORDER BY T2.horsepower DESC LIMIT 1;
#
# eval_err_num:65
# medium pred: SELECT max(MPG), COUNT(*) FROM cars_data WHERE year  1980 GROUP BY COUNT(*) DESC LIMIT 8
# medium gold: select max(mpg) from cars_data where cylinders  =  8 or year  <  1980
#
# eval_err_num:66
# extra pred: SELECT DISTINCT t1.model FROM models AS t1 JOIN cars_data AS t2 ON t1.model = t2.model WHERE t1.make = 'Ford Motor Company' AND t1.weight  3500
# extra gold: SELECT DISTINCT T1.model FROM MODEL_LIST AS T1 JOIN CAR_NAMES AS T2 ON T1.Model  =  T2.Model JOIN CARS_DATA AS T3 ON T2.MakeId  =  T3.Id JOIN CAR_MAKERS AS T4 ON T1.Maker  =  T4.Id WHERE T3.weight  <  3500 AND T4.FullName != 'Ford Motor Company';
#
# eval_err_num:67
# extra pred: SELECT DISTINCT TYPE FROM cars_data WHERE weight > 3500 INTERSECT SELECT DISTINCT TYPE FROM cars_data WHERE weight  3500 INTERSECT SELECT DISTINCT TYPE FROM cars_data WHERE weight  3500 INTERSECT SELECT DISTINCT TYPE FROM cars_data WHERE weight  3500
# extra gold: SELECT DISTINCT T1.model FROM MODEL_LIST AS T1 JOIN CAR_NAMES AS T2 ON T1.Model  =  T2.Model JOIN CARS_DATA AS T3 ON T2.MakeId  =  T3.Id JOIN CAR_MAKERS AS T4 ON T1.Maker  =  T4.Id WHERE T3.weight  <  3500 AND T4.FullName != 'Ford Motor Company';
#
# eval_err_num:68
# extra pred: SELECT T1.CountryId, T1.CountryName FROM countries AS T1 JOIN car_makers AS T2 ON T1.CountryId = T2.CountryId WHERE T2.Make = "fiat" GROUP BY T1.CountryId HAVING count(*) > 3
# extra gold: SELECT T1.countryId ,  T1.CountryName FROM Countries AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country GROUP BY T1.countryId HAVING count(*)  >  3 UNION SELECT T1.countryId ,  T1.CountryName FROM Countries AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country JOIN MODEL_LIST AS T3 ON T2.Id  =  T3.Maker WHERE T3.Model  =  'fiat';
#
# eval_err_num:69
# extra pred: SELECT T1.CountryId, T1.CountryName FROM countries AS T1 JOIN car_makers AS T2 ON T1.CountryId = T2.CountryId GROUP BY T1.CountryId HAVING COUNT(*) > 3
# extra gold: select t1.countryid ,  t1.countryname from countries as t1 join car_makers as t2 on t1.countryid  =  t2.country group by t1.countryid having count(*)  >  3 union select t1.countryid ,  t1.countryname from countries as t1 join car_makers as t2 on t1.countryid  =  t2.country join model_list as t3 on t2.id  =  t3.maker where t3.model  =  'fiat';
#
# easy pred: SELECT Country FROM airlines WHERE Abbreviation = "JetBlue Airways"
# easy gold: SELECT Country FROM AIRLINES WHERE Airline  =  "JetBlue Airways"
#
# eval_err_num:70
# medium pred: SELECT T1.Airline, T1.Abbreviation FROM airlines AS T1 JOIN flights AS T2 ON T1.Airline = T2.Airline WHERE T2.Country = "USA"
# medium gold: SELECT Airline ,  Abbreviation FROM AIRLINES WHERE Country  =  "USA"
#
# medium pred: SELECT T1.Airline, T1.Abbreviation FROM airlines AS T1 JOIN flights AS T2 ON T1.Airline = T2.Airline WHERE T1.Country = "USA"
# medium gold: SELECT Airline ,  Abbreviation FROM AIRLINES WHERE Country  =  "USA"
#
# medium pred: SELECT AirportCode, AirportName FROM airports WHERE CountryAbbrev = "Antonia"
# medium gold: SELECT AirportCode ,  AirportName FROM AIRPORTS WHERE city  =  "Anthony"
#
# eval_err_num:71
# medium pred: SELECT AirportCode, AirportName FROM airports WHERE CountryAbbreviation = "Antonio"
# medium gold: SELECT AirportCode ,  AirportName FROM AIRPORTS WHERE city  =  "Anthony"
#
# easy pred: SELECT Airline FROM airlines WHERE Airline = "UAL"
# easy gold: SELECT Airline FROM AIRLINES WHERE Abbreviation  =  "UAL"
#
# easy pred: SELECT Airline FROM airlines WHERE Airline = "UAL"
# easy gold: SELECT Airline FROM AIRLINES WHERE Abbreviation  =  "UAL"
#
# eval_err_num:72
# easy pred: SELECT AirportName FROM airports WHERE Airline = "AKO"
# easy gold: SELECT AirportName FROM AIRPORTS WHERE AirportCode  =  "AKO"
#
# eval_err_num:73
# easy pred: SELECT AirportName FROM airports WHERE Airline = "AKO"
# easy gold: SELECT AirportName FROM AIRPORTS WHERE AirportCode  =  "AKO"
#
# easy pred: SELECT AirportName FROM airports WHERE CountryAbbrev = "Boston"
# easy gold: SELECT AirportName FROM AIRPORTS WHERE City = "Aberdeen"
#
# eval_err_num:74
# easy pred: SELECT AirportName FROM airports WHERE CountryAbbreviation = "Boston"
# easy gold: SELECT AirportName FROM AIRPORTS WHERE City = "Aberdeen"
#
# easy pred: SELECT count(*) FROM flights WHERE Airline = "APG"
# easy gold: SELECT count(*) FROM FLIGHTS WHERE SourceAirport  =  "APG"
#
# easy pred: SELECT count(*) FROM flights WHERE Airline = 'APG'
# easy gold: SELECT count(*) FROM FLIGHTS WHERE SourceAirport  =  "APG"
#
# eval_err_num:75
# easy pred: SELECT count(*) FROM flights AS T1 JOIN airports AS T2 ON T1.Airport = T2.Airport WHERE T2.AirportName = "ATO"
# easy gold: SELECT count(*) FROM FLIGHTS WHERE DestAirport  =  "ATO"
#
# easy pred: SELECT count(*) FROM flights WHERE Airline = "ATO"
# easy gold: SELECT count(*) FROM FLIGHTS WHERE DestAirport  =  "ATO"
#
# eval_err_num:76
# medium pred: SELECT count(*) FROM flights AS T1 JOIN airports AS T2 ON T1.Airport = T2.Airport WHERE T2.CountryAbbreviation = "Boston"
# medium gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.SourceAirport  =  T2.AirportCode WHERE T2.City  =  "Aberdeen"
#
# eval_err_num:77
# medium pred: SELECT count(*) FROM flights AS T1 JOIN airports AS T2 ON T1.Airport = T2.Airport WHERE T2.CountryAbbreviation = "Boston"
# medium gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.SourceAirport  =  T2.AirportCode WHERE T2.City  =  "Aberdeen"
#
# eval_err_num:78
# medium pred: SELECT count(*) FROM airlines AS T1 JOIN flights AS T2 ON T1.airline = T2.airline WHERE T2.countryAbbreviation = "Boston"
# medium gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode WHERE T2.City  =  "Aberdeen"
#
# eval_err_num:79
# medium pred: SELECT count(*) FROM airlines AS T1 JOIN flights AS T2 ON T1.airline = T2.airline WHERE T2.countryAbbreviation = "Boston"
# medium gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode WHERE T2.City  =  "Aberdeen"
#
# eval_err_num:80
# hard pred: SELECT count(*) FROM flights AS T1 JOIN airports AS T2 ON T1.Airport = T2.AirportCode WHERE T2.CountryAbbreviation = "Astenger" AND T1.AirportName = "Astenger"
# hard gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode JOIN AIRPORTS AS T3 ON T1.SourceAirport  =  T3.AirportCode WHERE T2.City  =  "Ashley" AND T3.City  =  "Aberdeen"
#
# eval_err_num:81
# hard pred: SELECT count(*) FROM flights AS T1 JOIN airports AS T2 ON T1.Airport = T2.Airport WHERE T1.Country = "Aberley" AND T2.Country = "Aberley"
# hard gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode JOIN AIRPORTS AS T3 ON T1.SourceAirport  =  T3.AirportCode WHERE T2.City  =  "Ashley" AND T3.City  =  "Aberdeen"
#
# medium pred: SELECT count(*) FROM flights AS T1 JOIN airlines AS T2 ON T1.airline = T2.airline WHERE T1.Airline = "JetBlue Airways"
# medium gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRLINES AS T2 ON T1.Airline  =  T2.uid WHERE T2.Airline = "JetBlue Airways"
#
# medium pred: SELECT count(*) FROM flights AS T1 JOIN airlines AS T2 ON T1.airline = T2.airline WHERE T1.Airline = "Jewblue Airways"
# medium gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRLINES AS T2 ON T1.Airline  =  T2.uid WHERE T2.Airline = "JetBlue Airways"
#
# medium pred: SELECT count(*) FROM flights WHERE Airline = 'United Airlines' AND FlightNo = 'ASY'
# medium gold: SELECT count(*) FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T2.Airline  =  T1.uid WHERE T1.Airline  =  "United Airlines" AND T2.DestAirport  =  "ASY"
#
# medium pred: SELECT count(*) FROM airlines AS T1 JOIN flights AS T2 ON T1.airline = T2.airline WHERE T1.country = "ASY"
# medium gold: SELECT count(*) FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T2.Airline  =  T1.uid WHERE T1.Airline  =  "United Airlines" AND T2.DestAirport  =  "ASY"
#
# eval_err_num:82
# medium pred: SELECT count(*) FROM flights WHERE Airline = "United Airlines" AND Abbreviation = "AHD"
# medium gold: SELECT count(*) FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T2.Airline  =  T1.uid WHERE T1.Airline  =  "United Airlines" AND T2.SourceAirport  =  "AHD"
#
# medium pred: SELECT count(*) FROM airlines WHERE Airline = "United Airlines" AND Abbreviation = "AHD"
# medium gold: SELECT count(*) FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T2.Airline  =  T1.uid WHERE T1.Airline  =  "United Airlines" AND T2.SourceAirport  =  "AHD"
#
# hard pred: SELECT count(*) FROM airlines AS T1 JOIN flights AS T2 ON T1.airline = T2.airline WHERE T1.country = "Aberdeen"
# hard gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode JOIN AIRLINES AS T3 ON T3.uid  =  T1.Airline WHERE T2.City  =  "Aberdeen" AND T3.Airline  =  "United Airlines"
#
# hard pred: SELECT count(*) FROM airlines AS T1 JOIN flights AS T2 ON T1.airline = T2.airline WHERE T1.country = "Boston"
# hard gold: SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode JOIN AIRLINES AS T3 ON T3.uid  =  T1.Airline WHERE T2.City  =  "Aberdeen" AND T3.Airline  =  "United Airlines"
#
# medium pred: SELECT Airline FROM airlines WHERE Abbreviation = "AHD"
# medium gold: SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "AHD"
#
# medium pred: SELECT Airline FROM airlines WHERE Airline = "AHD"
# medium gold: SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "AHD"
#
# eval_err_num:83
# medium pred: SELECT Airline FROM airlines WHERE Airport = "AHD"
# medium gold: SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.DestAirport  =  "AHD"
#
# medium pred: SELECT Airline FROM airlines WHERE Airline = "AHD"
# medium gold: SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.DestAirport  =  "AHD"
#
# extra pred: SELECT Airline FROM flights WHERE Airline = "APG" INTERSECT SELECT Airline FROM flights WHERE Airline = "CVO"
# extra gold: SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "APG" INTERSECT SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "CVO"
#
# extra pred: SELECT Airline FROM airlines WHERE Airline = "APG" INTERSECT SELECT Airline FROM airlines WHERE Airline = "CVO"
# extra gold: SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "APG" INTERSECT SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "CVO"
#
# extra pred: SELECT Airline FROM flights WHERE FlightNo = 'CVO' INTERSECT SELECT Airline FROM flights WHERE FlightNo = 'APG'
# extra gold: SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "CVO" EXCEPT SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "APG"
#
# eval_err_num:84
# extra pred: SELECT T1.Airline FROM airlines AS T1 JOIN flights AS T2 ON T1.Airline = T2.Airline WHERE T1.Airline = "CVO" AND T2.AirportName = "APG"
# extra gold: SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "CVO" EXCEPT SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "APG"
#
# eval_err_num:85
# medium pred: SELECT FlightNo FROM airlines WHERE Airline = "United Airlines"
# medium gold: SELECT T1.FlightNo FROM FLIGHTS AS T1 JOIN AIRLINES AS T2 ON T2.uid  =  T1.Airline WHERE T2.Airline  =  "United Airlines"
#
# medium pred: SELECT FlightNo FROM flights WHERE Airline = "United Airlines"
# medium gold: SELECT T1.FlightNo FROM FLIGHTS AS T1 JOIN AIRLINES AS T2 ON T2.uid  =  T1.Airline WHERE T2.Airline  =  "United Airlines"
#
# easy pred: SELECT FlightNo FROM flights WHERE Airline = "APG"
# easy gold: SELECT FlightNo FROM FLIGHTS WHERE SourceAirport  =  "APG"
#
# easy pred: SELECT FlightNo FROM flights WHERE Airline = "APG"
# easy gold: SELECT FlightNo FROM FLIGHTS WHERE SourceAirport  =  "APG"
#
# easy pred: SELECT FlightNo FROM flights WHERE Airline = "APG"
# easy gold: SELECT FlightNo FROM FLIGHTS WHERE DestAirport  =  "APG"
#
# easy pred: SELECT FlightNo FROM flights WHERE Airline = "APG"
# easy gold: SELECT FlightNo FROM FLIGHTS WHERE DestAirport  =  "APG"
#
# medium pred: SELECT FlightNo FROM flights WHERE Airline = "Boston"
# medium gold: SELECT T1.FlightNo FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.SourceAirport   =  T2.AirportCode WHERE T2.City  =  "Aberdeen"
#
# medium pred: SELECT FlightNo FROM flights WHERE Airline = "Boston"
# medium gold: SELECT T1.FlightNo FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.SourceAirport   =  T2.AirportCode WHERE T2.City  =  "Aberdeen"
#
# eval_err_num:86
# medium pred: SELECT FlightNo FROM flights WHERE AirportName = "Boston"
# medium gold: SELECT T1.FlightNo FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport   =  T2.AirportCode WHERE T2.City  =  "Aberdeen"
#
# eval_err_num:87
# medium pred: SELECT FlightNo FROM flights WHERE Airport = "Boston"
# medium gold: SELECT T1.FlightNo FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport   =  T2.AirportCode WHERE T2.City  =  "Aberdeen"
#
# eval_err_num:88
# hard pred: SELECT count(*) FROM flights WHERE Country = "Aberley" OR Country = "Abilene"
# hard gold: SELECT count(*) FROM Flights AS T1 JOIN Airports AS T2 ON T1.DestAirport  =  T2.AirportCode WHERE T2.city  =  "Aberdeen" OR T2.city  =  "Abilene"
#
# eval_err_num:89
# hard pred: SELECT count(*) FROM flights AS T1 JOIN airports AS T2 ON T1.Airport = T2.Airport WHERE T1.Country = "Aberley" OR T1.Country = "Abilene"
# hard gold: SELECT count(*) FROM Flights AS T1 JOIN Airports AS T2 ON T1.DestAirport  =  T2.AirportCode WHERE T2.city  =  "Aberdeen" OR T2.city  =  "Abilene"
#
# eval_err_num:90
# hard pred: SELECT AirportName FROM airports WHERE AirportCode NOT IN (SELECT AirportCode FROM flights WHERE FlightNo = "in" INTERSECT SELECT AirportName FROM airports WHERE FlightNo = "out"
# hard gold: SELECT AirportName FROM Airports WHERE AirportCode NOT IN (SELECT SourceAirport FROM Flights UNION SELECT DestAirport FROM Flights)
#
# eval_err_num:91
# hard pred: SELECT T1.Airport FROM airports AS T1 JOIN flights AS T2 ON T1.Airport = T2.AirportCode WHERE T2.Airline = "Department" OR T1.Airline = "Ankunft"
# hard gold: SELECT AirportName FROM Airports WHERE AirportCode NOT IN (SELECT SourceAirport FROM Flights UNION SELECT DestAirport FROM Flights)
#
# eval_err_num:92
# easy pred: SELECT name, T1.name FROM employee AS T1 JOIN evaluation AS T2 ON T1.employee_id = T2.employee_id ORDER BY T2.age DESC LIMIT 1
# easy gold: SELECT name FROM employee ORDER BY age
#
# eval_err_num:93
# medium pred: SELECT city FROM employee WHERE age  30
# medium gold: SELECT city FROM employee WHERE age  <  30 GROUP BY city HAVING count(*)  >  1
#
# eval_err_num:94
# medium pred: SELECT city FROM employee WHERE age  30
# medium gold: SELECT city FROM employee WHERE age  <  30 GROUP BY city HAVING count(*)  >  1
#
# medium pred: SELECT count(*), LOCATION FROM shop
# medium gold: SELECT count(*) ,  LOCATION FROM shop GROUP BY LOCATION
#
# medium pred: SELECT count(*), LOCATION FROM shop
# medium gold: SELECT count(*) ,  LOCATION FROM shop GROUP BY LOCATION
#
# medium pred: SELECT name, LOCATION, district FROM shop ORDER BY Number_products DESC LIMIT 1
# medium gold: SELECT name ,  LOCATION ,  district FROM shop ORDER BY number_products DESC
#
# eval_err_num:95
# medium pred: SELECT name, LOCATION, district FROM shop ORDER BY amount_products DESC
# medium gold: SELECT name ,  LOCATION ,  district FROM shop ORDER BY number_products DESC
#
# hard pred: SELECT Name FROM shop GROUP BY Name HAVING avg(Number_products) > (SELECT avg(Number_products) FROM shop)
# hard gold: SELECT name FROM shop WHERE number_products  >  (SELECT avg(number_products) FROM shop)
#
# eval_err_num:96
# hard pred: SELECT name FROM shop GROUP BY name HAVING avg(shop_id) > (SELECT avg(shop_id) FROM merchandise)
# hard gold: SELECT name FROM shop WHERE number_products  >  (SELECT avg(number_products) FROM shop)
#
# eval_err_num:97
# hard pred: SELECT T1.Name FROM employee AS T1 JOIN hiring AS T2 ON T1.Employee_ID = T2.Employee_ID ORDER BY T1.Year_awarded DESC LIMIT 1
# hard gold: SELECT t1.name FROM employee AS t1 JOIN evaluation AS t2 ON t1.Employee_ID  =  t2.Employee_ID ORDER BY t2.bonus DESC LIMIT 1
#
# extra pred: SELECT T1.Name FROM shop AS T1 JOIN hiring AS T2 ON T1.Shop_ID = T2.Shop_ID GROUP BY T1.Name ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT t2.name FROM hiring AS t1 JOIN shop AS t2 ON t1.shop_id  =  t2.shop_id GROUP BY t1.shop_id ORDER BY count(*) DESC LIMIT 1
#
# extra pred: SELECT name FROM shop GROUP BY name ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT t2.name FROM hiring AS t1 JOIN shop AS t2 ON t1.shop_id  =  t2.shop_id GROUP BY t1.shop_id ORDER BY count(*) DESC LIMIT 1
#
# eval_err_num:98
# hard pred: SELECT name FROM shop WHERE shop_id NOT IN (SELECT shop_id FROM employee)
# hard gold: SELECT name FROM shop WHERE shop_id NOT IN (SELECT shop_id FROM hiring)
#
# eval_err_num:99
# hard pred: SELECT district FROM shop WHERE number_products  3000 INTERSECT SELECT district FROM shop WHERE number_products  10000
# hard gold: SELECT district FROM shop WHERE Number_products  <  3000 INTERSECT SELECT district FROM shop WHERE Number_products  >  10000
#
# eval_err_num:100
# hard pred: SELECT district FROM shop WHERE number_products  3000 INTERSECT SELECT district FROM shop WHERE number_products  10000
# hard gold: SELECT district FROM shop WHERE Number_products  <  3000 INTERSECT SELECT district FROM shop WHERE Number_products  >  10000
#
# easy pred: SELECT Name FROM teacher ORDER BY Age ASC LIMIT 1
# easy gold: SELECT Name FROM teacher ORDER BY Age ASC
#
# eval_err_num:101
# easy pred: SELECT T1.Name FROM teacher AS T1 JOIN teacher AS T2 ON T1.Teacher_ID = T2.Teacher_ID JOIN course AS T3 ON T1.Course_ID = T3.Course_ID WHERE T3.Age = "July" INTERSECT SELECT T1.Name FROM teacher AS T1 JOIN course_arrange AS T2 ON T1.Course_ID = T2.Course_ID WHERE T2.Teacher_ID = T2.
# easy gold: SELECT Name FROM teacher ORDER BY Age ASC
#
# easy pred: SELECT T1.Name FROM teacher AS T1 JOIN teacher AS T2 ON T1.Teacher_ID = T2.Teacher_ID WHERE T2.Hometown = "Low Lever Urban District"
# easy gold: select name from teacher where hometown != "little lever urban district"
#
# easy pred: SELECT T1.Name FROM teacher AS T1 JOIN teacher AS T2 ON T1.Teacher_ID = T2.Teacher_ID WHERE T2.Hometown = "Low Lever Urban District"
# easy gold: select name from teacher where hometown != "little lever urban district"
#
# medium pred: SELECT T1.Name FROM teacher AS T1 JOIN teacher AS T2 ON T1.Teacher_ID = T2.Teacher_ID WHERE T1.Name = 32 OR T2.Name = 33
# medium gold: SELECT Name FROM teacher WHERE Age  =  32 OR Age  =  33
#
# medium pred: SELECT Hometown FROM teacher ORDER BY Age DESC LIMIT 1
# medium gold: SELECT Hometown FROM teacher ORDER BY Age ASC LIMIT 1
#
# medium pred: SELECT name FROM teacher ORDER BY age DESC LIMIT 1
# medium gold: SELECT Hometown FROM teacher ORDER BY Age ASC LIMIT 1
#
# hard pred: SELECT T1.Name FROM teacher AS T1 JOIN teacher AS T2 ON T1.Teacher_ID = T2.Teacher_ID WHERE T2.Name = "Mathematik"
# hard gold: SELECT T3.Name FROM course_arrange AS T1 JOIN course AS T2 ON T1.Course_ID  =  T2.Course_ID JOIN teacher AS T3 ON T1.Teacher_ID  =  T3.Teacher_ID WHERE T2.Course  =  "Math"
#
# hard pred: SELECT T1.Name FROM teacher AS T1 JOIN teacher AS T2 ON T1.Teacher_ID = T2.Teacher_ID WHERE T2.Name = "Math"
# hard gold: SELECT T3.Name FROM course_arrange AS T1 JOIN course AS T2 ON T1.Course_ID  =  T2.Course_ID JOIN teacher AS T3 ON T1.Teacher_ID  =  T3.Teacher_ID WHERE T2.Course  =  "Math"
#
# eval_err_num:102
# hard pred: SELECT T1.Name FROM teacher AS T1 JOIN course AS T2 ON T1.Teacher_ID = T2.Teacher_ID
# hard gold: SELECT Name FROM teacher WHERE Teacher_id NOT IN (SELECT Teacher_id FROM course_arrange)
#
# eval_err_num:103
# hard pred: SELECT T2.Name FROM course AS T1 JOIN teacher AS T2 ON T1.Teacher_ID = T2.Teacher_ID
# hard gold: SELECT Name FROM teacher WHERE Teacher_id NOT IN (SELECT Teacher_id FROM course_arrange)
#
# eval_err_num:104
# easy pred: SELECT count(*) FROM visitor WHERE age  30
# easy gold: SELECT count(*) FROM visitor WHERE age  <  30
#
# medium pred: SELECT name FROM visitor WHERE level_of_membership > 4 ORDER BY level_of_membership ASC
# medium gold: SELECT name FROM visitor WHERE Level_of_membership  >  4 ORDER BY Level_of_membership DESC
#
# eval_err_num:105
# easy pred: SELECT avg(age) FROM visitor WHERE age  4
# easy gold: SELECT avg(age) FROM visitor WHERE Level_of_membership  <=  4
#
# eval_err_num:106
# medium pred: SELECT T1.Museum_ID, T1.Name FROM museum AS T1 JOIN visitor AS T2 ON T1.Museum_ID = T2.Museum_ID GROUP BY T1.Museum_ID ORDER BY count(*) DESC LIMIT 1
# medium gold: SELECT museum_id ,  name FROM museum ORDER BY num_of_staff DESC LIMIT 1
#
# eval_err_num:107
# easy pred: SELECT avg(Num_of_Staff) FROM museum WHERE Open_Year  2009
# easy gold: SELECT avg(num_of_staff) FROM museum WHERE open_year  <  2009
#
# eval_err_num:108
# medium pred: SELECT open_year, staff FROM museum WHERE name = "Palacitum Museum"
# medium gold: SELECT Num_of_Staff ,  Open_Year FROM museum WHERE name  =  'Plaza Museum'
#
# hard pred: SELECT name FROM museum WHERE open_year > 2010 GROUP BY name HAVING count(*) > 1
# hard gold: SELECT name FROM museum WHERE num_of_staff  >  (SELECT min(num_of_staff) FROM museum WHERE open_year  >  2010)
#
# medium pred: SELECT id, name, age FROM visitor GROUP BY id HAVING count(*) > 1
# medium gold: SELECT t1.id ,  t1.name ,  t1.age FROM visitor AS t1 JOIN visit AS t2 ON t1.id  =  t2.visitor_id GROUP BY t1.id HAVING count(*)  >  1
#
# eval_err_num:109
# extra pred: SELECT id, name, membership FROM visitor ORDER BY sum(total_spent) DESC LIMIT 1
# extra gold: SELECT t2.visitor_id ,  t1.name ,  t1.Level_of_membership FROM visitor AS t1 JOIN visit AS t2 ON t1.id  =  t2.visitor_id GROUP BY t2.visitor_id ORDER BY sum(t2.Total_spent) DESC LIMIT 1
#
# eval_err_num:110
# extra pred: SELECT T1.Museum_ID, T1.Name FROM visitor AS T1 JOIN museum AS T2 ON T1.Museum_ID = T2.Museum_ID GROUP BY T1.Museum_ID ORDER BY count(*) DESC LIMIT 1
# ...
#
# eval_err_num:271
# medium pred: SELECT count(*) FROM likes AS T1 JOIN Highschooler AS T2 ON T1.id = T2.friend_id WHERE T1.name = 'Kay'
# medium gold: SELECT count(*) FROM Likes AS T1 JOIN Highschooler AS T2 ON T1.student_id  =  T2.id WHERE T2.name  =  "Kyle"
#
# eval_err_num:272
# hard pred: SELECT avg(T1.grade) FROM student AS T1 JOIN Friend AS T2 ON T1.student_id = T2.friend_id GROUP BY T1.student_id
# hard gold: SELECT avg(grade) FROM Highschooler WHERE id IN (SELECT T1.student_id FROM Friend AS T1 JOIN Highschooler AS T2 ON T1.student_id  =  T2.id)
#
# eval_err_num:273
# hard pred: SELECT avg(T1.grade) FROM student AS T1 JOIN Friend AS T2 ON T1.student_id = T2.friend_id GROUP BY T1.student_id
# hard gold: SELECT avg(grade) FROM Highschooler WHERE id IN (SELECT T1.student_id FROM Friend AS T1 JOIN Highschooler AS T2 ON T1.student_id  =  T2.id)
#
# eval_err_num:274
# extra pred: SELECT min(T1.grade) FROM Friend AS T1 JOIN Friend AS T2 ON T1.student_id = T2.friend_id GROUP BY T1.student_id ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT min(grade) FROM Highschooler WHERE id NOT IN (SELECT T1.student_id FROM Friend AS T1 JOIN Highschooler AS T2 ON T1.student_id  =  T2.id)
#
# eval_err_num:275
# extra pred: SELECT DISTINCT grade FROM Friend AS T1 JOIN Friend AS T2 ON T1.student_id = T2.friend_id GROUP BY T1.student_id ORDER BY count(*) LIMIT 1
# extra gold: SELECT min(grade) FROM Highschooler WHERE id NOT IN (SELECT T1.student_id FROM Friend AS T1 JOIN Highschooler AS T2 ON T1.student_id  =  T2.id)
#
# eval_err_num:276
# extra pred: SELECT professional_id, last_name, cell_number FROM treatment WHERE city = "Indiana" AND cost_of_treatment > 2
# extra gold: SELECT professional_id ,  last_name ,  cell_number FROM Professionals WHERE state  =  'Indiana' UNION SELECT T1.professional_id ,  T1.last_name ,  T1.cell_number FROM Professionals AS T1 JOIN Treatments AS T2 ON T1.professional_id  =  T2.professional_id GROUP BY T1.professional_id HAVING count(*)  >  2
#
# extra pred: SELECT professional_id, last_name, cell_number FROM professionals WHERE city = "Indiana" AND cell_number > 2
# extra gold: SELECT professional_id ,  last_name ,  cell_number FROM Professionals WHERE state  =  'Indiana' UNION SELECT T1.professional_id ,  T1.last_name ,  T1.cell_number FROM Professionals AS T1 JOIN Treatments AS T2 ON T1.professional_id  =  T2.professional_id GROUP BY T1.professional_id HAVING count(*)  >  2
#
# eval_err_num:277
# hard pred: SELECT T1.name FROM Owners AS T1 JOIN Treatments AS T2 ON T1.owner_id = T2.owner_id GROUP BY T1.owner_id HAVING COUNT(*) > 1000
# hard gold: select name from dogs where dog_id not in ( select dog_id from treatments group by dog_id having sum(cost_of_treatment)  >  1000 )
#
# eval_err_num:278
# extra pred: SELECT owner_id, first_name, last_name FROM dogs GROUP BY owner_id ORDER BY count(*) DESC LIMIT 1
# extra gold: SELECT T1.owner_id ,  T2.first_name ,  T2.last_name FROM Dogs AS T1 JOIN Owners AS T2 ON T1.owner_id  =  T2.owner_id GROUP BY T1.owner_id ORDER BY count(*) DESC LIMIT 1
#
# eval_err_num:279
# medium pred: SELECT T1.treatment_id, T1.role_code, T1.first_name FROM Professionals AS T1 JOIN Treatments AS T2 ON T1.treatment_id = T2.treatment_id GROUP BY T1.professional_id HAVING count(*) >= 2
# medium gold: SELECT T1.professional_id ,  T1.role_code ,  T1.first_name FROM Professionals AS T1 JOIN Treatments AS T2 ON T1.professional_id  =  T2.professional_id GROUP BY T1.professional_id HAVING count(*)  >=  2
#
# eval_err_num:280
# medium pred: SELECT T1.professional_id, T1.role_code, T1.first_name FROM Professionals AS T1 JOIN Treatments AS T2 ON T1.treatment_id = T2.treatment_id GROUP BY T1.professional_id HAVING count(*) >= 2
# medium gold: SELECT T1.professional_id ,  T1.role_code ,  T1.first_name FROM Professionals AS T1 JOIN Treatments AS T2 ON T1.professional_id  =  T2.professional_id GROUP BY T1.professional_id HAVING count(*)  >=  2
#
# eval_err_num:281
# extra pred: SELECT treatment_type_description FROM treatment ORDER BY cost_of_treatment DESC LIMIT 1
# extra gold: SELECT T1.treatment_type_description FROM Treatment_types AS T1 JOIN Treatments AS T2 ON T1.treatment_type_code  =  T2.treatment_type_code GROUP BY T1.treatment_type_code ORDER BY sum(cost_of_treatment) ASC LIMIT 1
#
# eval_err_num:282
# extra pred: SELECT treatment_type_description FROM treatment ORDER BY cost_of_treatment LIMIT 1
# extra gold: SELECT T1.treatment_type_description FROM Treatment_types AS T1 JOIN Treatments AS T2 ON T1.treatment_type_code  =  T2.treatment_type_code GROUP BY T1.treatment_type_code ORDER BY sum(cost_of_treatment) ASC LIMIT 1
#
# eval_err_num:283
# extra pred: SELECT id, zip_code FROM dogs ORDER BY sum(total) DESC LIMIT 1
# extra gold: SELECT T1.owner_id ,  T1.zip_code FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id  =  T2.owner_id JOIN Treatments AS T3 ON T2.dog_id  =  T3.dog_id GROUP BY T1.owner_id ORDER BY sum(T3.cost_of_treatment) DESC LIMIT 1
#
# eval_err_num:284
# extra pred: SELECT owner_id, zip_code FROM dogs GROUP BY owner_id ORDER BY sum(cost_of_treatment) DESC LIMIT 1
# extra gold: SELECT T1.owner_id ,  T1.zip_code FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id  =  T2.owner_id JOIN Treatments AS T3 ON T2.dog_id  =  T3.dog_id GROUP BY T1.owner_id ORDER BY sum(T3.cost_of_treatment) DESC LIMIT 1
#
# eval_err_num:285
# extra pred: SELECT first_name, last_name FROM professionals WHERE cost_of_treatment  (SELECT avg(cost_of_treatment) FROM treatment)
# extra gold: SELECT DISTINCT T1.first_name ,  T1.last_name FROM Professionals AS T1 JOIN Treatments AS T2 WHERE cost_of_treatment  <  ( SELECT avg(cost_of_treatment) FROM Treatments )
#
# eval_err_num:286
# extra pred: SELECT T1.first_name, T1.last_name FROM Professionals AS T1 JOIN Treatment_Types AS T2 ON T1.treatment_type_code = T2.treatment_type_code WHERE T2.last_name  (SELECT avg(cost_of_treatment) FROM Treatments)
# extra gold: SELECT DISTINCT T1.first_name ,  T1.last_name FROM Professionals AS T1 JOIN Treatments AS T2 WHERE cost_of_treatment  <  ( SELECT avg(cost_of_treatment) FROM Treatments )
#
# eval_err_num:287
# medium pred: SELECT T1.owner_id, T1.name FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id = T2.owner_id WHERE T2.city = "Virgina"
# medium gold: SELECT T1.first_name ,  T2.name FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id  =  T2.owner_id WHERE T1.state  =  'Virginia'
#
# eval_err_num:288
# medium pred: SELECT T1.first_name, T1.last_name FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id = T2.owner_id WHERE T2.city = "Virgina" INTERSECT SELECT T1.first_name, T1.last_name FROM Owners AS T1 JOIN Treatment_Types AS T2 ON T1.treatment_type_code = T2.treatment_type_code WHERE T2.city = "dog" ;
# medium gold: SELECT T1.first_name ,  T2.name FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id  =  T2.owner_id WHERE T1.state  =  'Virginia'
#
# extra pred: SELECT T1.last_name FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id = T2.owner_id ORDER BY T2.age DESC LIMIT 1
# extra gold: SELECT T1.last_name FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id  =  T2.owner_id WHERE T2.age  =  ( SELECT max(age) FROM Dogs )
#
# eval_err_num:289
# extra pred: SELECT T1.name FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id = T2.owner_id ORDER BY T2.age DESC LIMIT 1
# extra gold: SELECT T1.last_name FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id  =  T2.owner_id WHERE T2.age  =  ( SELECT max(age) FROM Dogs )
#
# medium pred: SELECT email_address FROM Professionals WHERE city = "Hawaii" OR city = "WIWTO"
# medium gold: SELECT email_address FROM Professionals WHERE state  =  'Hawaii' OR state  =  'Wisconsin'
#
# medium pred: SELECT email_address FROM Professionals WHERE city = "Hawaii" OR city = "Wichigan"
# medium gold: SELECT email_address FROM Professionals WHERE state  =  'Hawaii' OR state  =  'Wisconsin'
#
# eval_err_num:290
# hard pred: SELECT count(*) FROM dogs WHERE age  (SELECT avg(age) FROM dogs)
# hard gold: SELECT count(*) FROM Dogs WHERE age  <  ( SELECT avg(age) FROM Dogs )
#
# eval_err_num:291
# hard pred: SELECT count(*) FROM dogs WHERE age  (SELECT avg(age) FROM dogs)
# hard gold: SELECT count(*) FROM Dogs WHERE age  <  ( SELECT avg(age) FROM Dogs )
#
# eval_err_num:292
# medium pred: SELECT sum(date_of_treatment) FROM treatment GROUP BY date_of_treatment ORDER BY date_of_treatment DESC LIMIT 1
# medium gold: SELECT cost_of_treatment FROM Treatments ORDER BY date_of_treatment DESC LIMIT 1
#
# eval_err_num:293
# medium pred: SELECT T1.name, T2.age, T2.weight FROM Dogs AS T1 JOIN Treatment_Types AS T2 ON T1.treatment_type_code = T2.treatment_type_code JOIN Dogs AS T3 ON T2.dog_id = T3.dog_id WHERE T3.name = "Abandoned"
# medium gold: SELECT name ,  age ,  weight FROM Dogs WHERE abandoned_yn  =  1
#
# eval_err_num:294
# medium pred: SELECT T1.name, T2.age, T2.weight FROM Dogs AS T1 JOIN Treatment_Types AS T2 ON T1.treatment_type_code = T2.treatment_type_code WHERE T2.name = "Abandoned"
# medium gold: SELECT name ,  age ,  weight FROM Dogs WHERE abandoned_yn  =  1
#
# easy pred: SELECT Name FROM singer WHERE Name!= "France"
# easy gold: SELECT Name FROM singer WHERE Citizenship != "France"
#
# eval_err_num:295
# easy pred: SELECT T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID = T2.Singer_ID WHERE T2.Name = "France"
# easy gold: SELECT Name FROM singer WHERE Citizenship != "France"
#
# eval_err_num:296
# medium pred: SELECT Nationality, COUNT(*) FROM singer GROUP BY Nationality
# medium gold: SELECT Citizenship ,  COUNT(*) FROM singer GROUP BY Citizenship
#
# eval_err_num:297
# medium pred: SELECT count(*), country FROM singer GROUP BY country
# medium gold: SELECT Citizenship ,  COUNT(*) FROM singer GROUP BY Citizenship
#
# eval_err_num:298
# hard pred: SELECT nationality FROM singer GROUP BY nationality ORDER BY count(*) DESC LIMIT 1
# hard gold: SELECT Citizenship FROM singer GROUP BY Citizenship ORDER BY COUNT(*) DESC LIMIT 1
#
# hard pred: SELECT DISTINCT T1.name FROM singer AS T1 JOIN song AS T2 ON T1.singer_id = T2.singer_id JOIN singer AS T3 ON T2.singer_id = T3.singer_id WHERE T3.name = "Msot"
# hard gold: select citizenship from singer group by citizenship order by count(*) desc limit 1
#
# eval_err_num:299
# medium pred: SELECT Nationalities, max(Net_Worth_Millions) FROM singer GROUP BY Nationality
# medium gold: SELECT Citizenship ,  max(Net_Worth_Millions) FROM singer GROUP BY Citizenship
#
# eval_err_num:300
# medium pred: SELECT country, max(Net_Worth_Millions) FROM singer GROUP BY country
# medium gold: SELECT Citizenship ,  max(Net_Worth_Millions) FROM singer GROUP BY Citizenship
#
# eval_err_num:301
# hard pred: SELECT Citizenship FROM singer WHERE Birth_Year  1945 INTERSECT SELECT Citizenship FROM singer WHERE Birth_Year > 1955
# hard gold: SELECT Citizenship FROM singer WHERE Birth_Year  <  1945 INTERSECT SELECT Citizenship FROM singer WHERE Birth_Year  >  1955
#
# hard pred: SELECT Citizenship FROM singer WHERE Birth_Year > 1945 INTERSECT SELECT Citizenship FROM singer WHERE Birth_Year > 1955
# hard gold: SELECT Citizenship FROM singer WHERE Birth_Year  <  1945 INTERSECT SELECT Citizenship FROM singer WHERE Birth_Year  >  1955
#
# eval_err_num:302
# hard pred: SELECT T1.property_name FROM Properties AS T1 JOIN Other_Available_Features AS T2 ON T1.property_id = T2.property_id GROUP BY T1.property_name HAVING count(*) > 1
# hard gold: SELECT property_name FROM Properties WHERE property_type_code  =  "House" UNION SELECT property_name FROM Properties WHERE property_type_code  =  "Apartment" AND room_count  >  1
#
#                      easy                 medium               hard                 extra                all
# count                109                  203                  99                   97                   508
# =====================   EXECUTION ACCURACY     =====================
# execution            0.312                0.222                0.081                0.052                0.181
#
# ====================== EXACT MATCHING ACCURACY =====================
# exact match          0.330                0.182                0.061                0.031                0.161
#
# ---------------------PARTIAL MATCHING ACCURACY----------------------
# select               0.958                0.902                0.852                0.800                0.908
# select(no AGG)       0.958                0.913                0.852                0.800                0.913
# where                0.456                0.420                0.188                0.300                0.398
# where(no OP)         0.544                0.420                0.250                0.300                0.444
# group(no Having)     0.714                0.667                0.250                0.400                0.553
# group                0.714                0.667                0.250                0.200                0.526
# order                0.556                0.393                0.500                0.600                0.463
# and/or               1.000                0.892                0.818                0.833                0.890
# IUEN                 0.000                0.000                1.000                0.000                0.125
# keywords             0.901                0.800                0.630                0.600                0.798
# ---------------------- PARTIAL MATCHING RECALL ----------------------
# select               0.633                0.409                0.232                0.124                0.368
# select(no AGG)       0.633                0.414                0.232                0.124                0.370
# where                0.292                0.165                0.043                0.040                0.147
# where(no OP)         0.348                0.165                0.057                0.040                0.163
# group(no Having)     0.714                0.300                0.143                0.065                0.228
# group                0.714                0.300                0.143                0.032                0.217
# order                0.385                0.256                0.261                0.100                0.229
# and/or               1.000                1.000                1.000                0.988                0.998
# IUEN                 0.000                0.000                0.050                0.000                0.021
# keywords             0.587                0.355                0.172                0.093                0.319
# ---------------------- PARTIAL MATCHING F1 --------------------------
# select               0.762                0.563                0.365                0.214                0.524
# select(no AGG)       0.762                0.569                0.365                0.214                0.527
# where                0.356                0.237                0.070                0.071                0.215
# where(no OP)         0.425                0.237                0.093                0.071                0.239
# group(no Having)     0.714                0.414                0.182                0.111                0.323
# group                0.714                0.414                0.182                0.056                0.308
# order                0.455                0.310                0.343                0.171                0.307
# and/or               1.000                0.943                0.900                0.904                0.941
# IUEN                 1.000                1.000                0.095                1.000                0.036
# keywords             0.711                0.491                0.270                0.161                0.456
